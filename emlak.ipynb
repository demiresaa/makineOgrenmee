# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('C:/Users/Dell/Desktop/makineOgrenme/emlak.csv.txt',sep=";") # ; işareti ile sutunlara ayırdık

# %%
data.head()
# Out:
#    alan  odaSayisi  binaYasi     fiyat
# 0   180          5        10   5000000
# 1   225          4        18   6000000
# 2   380          6         2   8000000
# 3   320          7         8   7500000
# 4   355          8        10  10000000

# %%
# !pip install scikit-learn
from sklearn import linear_model
ml = linear_model.LinearRegression()

# %%
X=data.iloc[:,0:-1]
X
# Out:
#    alan  odaSayisi  binaYasi
# 0   180          5        10
# 1   225          4        18
# 2   380          6         2
# 3   320          7         8
# 4   355          8        10
# 5   340          7        14
# 6   354         10         0
# 7   400         11         7

# %%
y=data.iloc[:,-1].values

# %%
y
# Out:
# array([ 5000000,  6000000,  8000000,  7500000, 10000000, 11000000,
#        12000000, 20000000], dtype=int64)

# %%
ml.fit(X,y)
# Out:
# LinearRegression()

# %%
ml.predict([[280,6,10]])
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([7492213.58795838])

# %%
import pickle

# %%
model="fiyatTahmin.pickle"

# %%
pickle.dump(ml,open(model,"wb")) 
# burada pickle kütüphanesi ile modelimizi kayıt ettik pc ye
